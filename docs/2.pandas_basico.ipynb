# %% [markdown]
# # Introducción a Pandas
#
# En este notebook aprenderemos cómo leer datos en un `DataFrame` y algunas herramientas básicas de Pandas.

# %% [markdown]
# ## Instalación y Importación de Pandas
# Para usar Pandas, primero debemos instalarlo (si no lo tenemos) y luego importarlo en nuestro código.

# %%
# Instalar pandas (si no está instalado)
# !pip install pandas

# %%
# Importar pandas
import pandas as pd

# %% [markdown]
# ## Lectura de Datos con Pandas
# Podemos leer diferentes tipos de archivos como CSV, Excel o JSON usando Pandas.

# %%
df = pd.read_excel('CIE10.xlsx')  
df
# Out:
#       COD_3 DESRIPCION CATEGORIAS DE TRES CARACTERES COD_4  \
# 0       A00                                   COLERA  A000
# 1       NaN                                      NaN  A001
# 2       NaN                                      NaN  A009
# 3       A01          FIEBRES TIFOIDEA Y PARATIFOIDEA  A010
# 4       NaN                                      NaN  A011
# ...     ...                                      ...   ...
# 12418   NaN                                      NaN  Z991
# 12419   NaN                                      NaN  Z992
# 12420   NaN                                      NaN  Z993
# 12421   NaN                                      NaN  Z998
# 12422   NaN                                      NaN  Z999
#
#                 DESCRIPCION CODIGOS DE CUATRO CARACTERES
# 0      COLERA DEBIDO A VIBRIO CHOLERAE O1, BIOTIPO CH...
# 1      COLERA DEBIDO A VIBRIO CHOLERAE O1, BIOTIPO EL...
# 2                                 COLERA NO ESPECIFICADO
# ...

# %% [markdown]
# ## EDA Básico del DataFrame

# %%
df.head()
# Out:
#   COD_3 DESRIPCION CATEGORIAS DE TRES CARACTERES COD_4  \
# 0   A00                                   COLERA  A000
# 1   NaN                                      NaN  A001
# 2   NaN                                      NaN  A009
# 3   A01          FIEBRES TIFOIDEA Y PARATIFOIDEA  A010
# 4   NaN                                      NaN  A011
#
#             DESCRIPCION CODIGOS DE CUATRO CARACTERES
# 0  COLERA DEBIDO A VIBRIO CHOLERAE O1, BIOTIPO CH...
# 1  COLERA DEBIDO A VIBRIO CHOLERAE O1, BIOTIPO EL...
# 2                             COLERA NO ESPECIFICADO
# 3                                    FIEBRE TIFOIDEA
# 4                              FIEBRE PARATIFOIDEA A

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12423 entries, 0 to 12422
# Data columns (total 4 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   COD_3                                     2037 non-null   object
#  1   DESRIPCION CATEGORIAS DE TRES CARACTERES  2036 non-null   object
#  2   COD_4                                     12423 non-null  object
#  3   DESCRIPCION CODIGOS DE CUATRO CARACTERES  12423 non-null  object
# dtypes: object(4)
# memory usage: 388.3+ KB

# %%
df.describe()
# Out:
#        COD_3 DESRIPCION CATEGORIAS DE TRES CARACTERES  COD_4  \
# count   2037                                     2036  12423
# unique  2037                                     2036  12423
# top      A00                                   COLERA   A000
# freq       1                                        1      1
#
#              DESCRIPCION CODIGOS DE CUATRO CARACTERES
# count                                           12423
# unique                                          12420
# top     OTRAS MALFORMACIONES CONGENITAS DE LA LARINGE
# freq                                                2

# %% [markdown]
# ## Selección y Filtrado de Datos

# %%
nombre_columna = 'COD_3'
print(df[nombre_columna])

# %%
(df[['COD_3', 'COD_4']])
# Out:
#       COD_3 COD_4
# 0       A00  A000
# 1       NaN  A001
# 2       NaN  A009
# 3       A01  A010
# 4       NaN  A011
# ...     ...   ...
# 12418   NaN  Z991
# 12419   NaN  Z992
# 12420   NaN  Z993
# 12421   NaN  Z998
# 12422   NaN  Z999
#
# [12423 rows x 2 columns]

# %%
df[df['COD_3']=='A01']
# Out:
#   COD_3 DESRIPCION CATEGORIAS DE TRES CARACTERES COD_4  \
# 3   A01          FIEBRES TIFOIDEA Y PARATIFOIDEA  A010
#
#   DESCRIPCION CODIGOS DE CUATRO CARACTERES
# 3                          FIEBRE TIFOIDEA

# %% [markdown]
# ## Operaciones Básicas con Columnas

# %%
df['nueva_columna'] = df['columna1'] * 2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\loren\miniconda3\envs\venv_py\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'columna1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['nueva_columna'] = df['columna1'] * 2
# ...

# %%
# Eliminar una columna
df = df.drop(columns=['columna_a_eliminar'])
print(df.head())

# %% [markdown]
# ## Conclusión
# Hemos aprendido cómo leer datos en un `DataFrame` y aplicar herramientas básicas en Pandas. Esto es fundamental para el análisis y manipulación de datos en Python.
