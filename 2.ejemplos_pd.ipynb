# %% [markdown]
# # 📦 Funciones Principales de Pandas
#
# ## 📥 Lectura y Escritura de Datos
#
# ```python
# pd.read_csv('archivo.csv')            # Leer archivo CSV
# pd.read_excel('archivo.xlsx')         # Leer archivo Excel
# pd.read_sql(query, conexion)          # Leer desde base de datos SQL
# pd.read_json('archivo.json')          # Leer archivo JSON
#
# df.to_csv('archivo.csv')              # Guardar a CSV
# df.to_excel('archivo.xlsx')           # Guardar a Excel
# df.to_json('archivo.json')            # Guardar a JSON
# ```
#
# ---
#
# ## 🧱 Creación de Objetos
#
# ```python
# pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})  # Crear un DataFrame
# ```
#
# ---
#
# ## 🔍 Exploración y Resumen
#
# ```python
# df.value_counts()                     # Conteo de valores unicos
# df.head()                             # Primeras filas
# df.tail()                             # Últimas filas
# df.info()                             # Información general
# df.describe()                         # Estadísticas descriptivas
# df.shape                              # Dimensiones
# df.columns                            # Nombres de columnas
# df.index                              # Índice del DataFrame
# df.dtypes                             # Tipos de datos
# ```
#
# ---
#
# ## 🔧 Selección y Filtrado
#
# ```python
# df['columna']                         # Seleccionar una columna
# df[['col1', 'col2']]                  # Seleccionar varias columnas
# df.loc[filas, columnas]               # Selección por etiquetas
# df.iloc[filas, columnas]              # Selección por posición
# df[df['col'] > 0]                     # Filtrado por condición
# ```
#
# ---
#
# ## 🔄 Modificación de Datos
#
# ```python
# df['nueva_col'] = df['col1'] + df['col2']       # Crear nueva columna
# df.rename(columns={'viejo': 'nuevo'})           # Renombrar columnas
# df.drop('columna', axis=1)                      # Eliminar columna
# df.drop(index=0)                                # Eliminar fila
# df.sort_values('columna')                       # Ordenar
# df.fillna(0)                                     # Rellenar NaNs
# df.dropna()                                      # Eliminar NaNs
# df.replace({'a': 'A'})                           # Reemplazar valores
# ```
#
# ---
#
# ## 🔗 Agrupación y Combinación
#
# ```python
# df.groupby('columna').mean()                    # Agrupación
# df.merge(df2, on='col')                         # Join entre DataFrames
# pd.concat([df1, df2])                           # Concatenación
# ```
#
#
#
# ## 📊 Estadísticas y Operaciones
#
# ```python
# df.mean()                                      # Promedio
# df.sum()                                       # Suma
# df.min(), df.max()                             # Mínimo y máximo
# df.std(), df.var()                             # Desviación y varianza
# df.corr()                                      # Correlación
# df.cumsum(), df.cumprod()                      # Acumulados
# ```
